# %%
import copy

import numpy as np
import cv2
import math
import os

# %%
def get_bits(string, num_bits=21):
    """
    Extracts chunks of bits from a string.
  
    Args:
      string: The string to extract bits from.
      num_bits: The number of bits to extract at a time.
  
    Returns:
      A list of strings, each containing num_bits bits from the input string.
    """

    # Convert the string to a binary string.
    binary_string = ''.join(format(ord(char), '08b') for char in string)

    # Pad the binary string with zeros if necessary.
    binary_string = binary_string.zfill(len(binary_string) + (num_bits - len(binary_string) % num_bits))

    # Split the binary string into chunks of num_bits.
    bits = [binary_string[i:i + num_bits] for i in range(0, len(binary_string), num_bits)]

    return bits


if __name__ == "__main__":
    # Get the input string from the user.
    string = input("Enter a string: ")

    # Extract the bits from the string.
    bits = get_bits(string)

    # Print the bits.
    print("Bits:")
    for bit in bits:
        print(bit)
# Out:
# Bits:
# 000000000000001110000

# %%
def extract_bits_from_word(word):
    """
    Извлекает биты из произвольного слова по 21 штуке.
  
    Args:
      word: Произвольное слово.
  
    Returns:
      Массив битов.
    """

    # Преобразуйте произвольное слово в двоичную строку.
    binary_string = bin(int.from_bytes(word.encode(), 'big'))[2:]

    # Определите начальную позицию в строке.
    start_position = 0

    # Создайте массив для хранения извлекаемых битов.
    bits = []

    # Войдите в цикл, который будет выполняться до тех пор, пока вы не достигнете конца строки.
    while start_position < len(binary_string):
        # Извлеките 21 бит из строки, начиная с текущей позиции.
        bits_to_extract = binary_string[start_position:start_position + 21]

        # Добавьте извлеченные биты в массив.
        bits.append(bits_to_extract)

        # Обновите текущую позицию в строке.
        start_position += 21

    # Верните массив битов.
    return bits


# Пример использования.
word = ("HHH")
bits = extract_bits_from_word(word)

print(bits)
# Out:
# ['100100001001000010010', '00']

# %%
from copy import deepcopy

# read input as grayscale
img = cv2.imread('lena.png', 0)

# convert image to floats and do dft saving as complex output
dft = cv2.dft(np.float32(img), flags=cv2.DFT_COMPLEX_OUTPUT)

# apply shift of origin from upper left corner to center of image
dft_shift = np.fft.fftshift(dft)

# extract magnitude and phase images
mag, phase = cv2.cartToPolar(dft_shift[:, :, 0], dft_shift[:, :, 1])
phase -= math.pi

# получение размеров изображения
height, width = phase.shape
print(height, width)

# количество блоков по вертикали и горизонтали
blocks_v = height // 8
blocks_h = width // 8

# convert magnitude and phase into cartesian real and imaginary components
real, imag = cv2.polarToCart(mag, phase)

# combine cartesian components into one complex image
back = cv2.merge([real, imag])

# shift origin from center to upper left corner
back_ishift = np.fft.ifftshift(back)

# do idft saving as complex output
img_back = cv2.idft(back_ishift)

# combine complex components into original image again
img_back = cv2.magnitude(img_back[:, :, 0], img_back[:, :, 1])

# cv2.imshow("ORIGINAL", img_back)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
cv2.imwrite("lena_grayscale_opencv.png", img_back)

# read input as grayscale
img = cv2.imread('lena_grayscale_opencv.png', 0)

# convert image to floats and do dft saving as complex output
dft = cv2.dft(np.float32(img), flags=cv2.DFT_COMPLEX_OUTPUT)

# apply shift of origin from upper left corner to center of image
dft_shift = np.fft.fftshift(dft)

# extract magnitude and phase images
mag, phase = cv2.cartToPolar(dft_shift[:, :, 0], dft_shift[:, :, 1])
# создание массива блоков
blocks = np.zeros((blocks_v * blocks_h, 8, 8))
mags = np.zeros((blocks_v * blocks_h, 8, 8))

# разделение изображения на блоки
for i in range(blocks_v):
    for j in range(blocks_h):
        block = phase[i * 8:(i + 1) * 8, j * 8:(j + 1) * 8]
        blocks[i * blocks_h + j] = block

for i in range(blocks_v):
    for j in range(blocks_h):
        block = phase[i * 8:(i + 1) * 8, j * 8:(j + 1) * 8]
        mags[i * blocks_h + j] = block

b = deepcopy(blocks[500])
m = deepcopy(mags[500])

# convert magnitude and phase into cartesian real and imaginary components
real, imag = cv2.polarToCart(mag, phase)

# combine cartesian components into one complex image
back = cv2.merge([real, imag])

# shift origin from center to upper left corner
back_ishift = np.fft.ifftshift(back)

# do idft saving as complex output
img_back = cv2.idft(back_ishift)

# combine complex components into original image again
img_back = cv2.magnitude(img_back[:, :, 0], img_back[:, :, 1])

# cv2.imshow("ORIGINAL", img_back)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
cv2.imwrite("lena_grayscale_opencv1.png", img_back)

# read input as grayscale
img = cv2.imread('lena_grayscale_opencv1.png', 0)

# convert image to floats and do dft saving as complex output
dft = cv2.dft(np.float32(img), flags=cv2.DFT_COMPLEX_OUTPUT)

# apply shift of origin from upper left corner to center of image
dft_shift = np.fft.fftshift(dft)

# extract magnitude and phase images
mag, phase = cv2.cartToPolar(dft_shift[:, :, 0], dft_shift[:, :, 1])

# создание массива блоков
blocks = np.zeros((blocks_v * blocks_h, 8, 8))
mags = np.zeros((blocks_v * blocks_h, 8, 8))

# разделение изображения на блоки
for i in range(blocks_v):
    for j in range(blocks_h):
        block = phase[i * 8:(i + 1) * 8, j * 8:(j + 1) * 8]
        blocks[i * blocks_h + j] = block

for i in range(blocks_v):
    for j in range(blocks_h):
        block = phase[i * 8:(i + 1) * 8, j * 8:(j + 1) * 8]
        mags[i * blocks_h + j] = block

# print(phase - math.pi)
# print(b)
phase = phase - math.pi
for i in range(len(b)):
    for j in range(len(b[0])):
        print(blocks[500][i][j] == b[i][j])
    print()
# Out:
# 256 256
# True
# True
# True
# True
# True
# True
# True
# True
#
# True
# True
# True
# True
# True
# True
# True
# True
#
# True
# True
# True
# True
# True
# True
# True
# True
#
# True
# True
# True
# True
# True
# True
# True
# True
#
# True
# True
# True
# True
# True
# True
# True
# True
#
# True
# True
# True
# True
# True
# True
# True
# True
#
# True
# True
# True
# True
# True
# True
# True
# True
#
# True
# True
# True
# True
# True
# True
# True
# True

# %%
# Получаем список файлов в директории
files = os.listdir("/Users/pavel/Desktop/watermark-embedder/src/resources/image")

# Печатаем список файлов
for file in files:
    if file.endswith(".png"):
        print(file)
# Out:
# peppers512.png
# goldhill512.png
# barbara512.png
# lena512.png
# baboon512.png
# boat512.png
# airplane512.png
# stream_and_bridge512.png

# %%
# read input as grayscale
img = cv2.imread('stream_and_bridge512.png', 0)

# convert image to floats and do dft saving as complex output
dft = cv2.dft(np.float32(img), flags = cv2.DFT_COMPLEX_OUTPUT)

# apply shift of origin from upper left corner to center of image
dft_shift = np.fft.fftshift(dft)

# extract magnitude and phase images
mag, phase = cv2.cartToPolar(dft_shift[:,:,0], dft_shift[:,:,1])

# convert magnitude and phase into cartesian real and imaginary components
real, imag = cv2.polarToCart(mag, phase)

# combine cartesian components into one complex image
back = cv2.merge([real, imag])

# shift origin from center to upper left corner
back_ishift = np.fft.ifftshift(back)

# do idft saving as complex output
img_back = cv2.idft(back_ishift)

# combine complex components into original image again
img_back = cv2.magnitude(img_back[:,:,0], img_back[:,:,1])

# re-normalize to 8-bits
img_back = cv2.normalize(img_back, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8U)


# write result to disk
cv2.imwrite("stream_and_bridge.png", img_back)
# Out:
# True
